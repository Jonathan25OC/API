# %% [markdown]
# # Introduccion a Matplotlib
#
# [Matplotlib](https://matplotlib.org)
# Es una biblioteca que permite la creacion de fifuras y graficos, de calidad mediente el uso de Python.
# * Permite la creacion de graficos de manera sencilla y eficiente.
# * Permite la integracion de graficos y figuras en un Jupyter Notebook.

# %% [markdown]
# ## import

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
# Muestra los graficos integrados dentro de Juppyter Notebook
# %matplotlib inline

# %% [markdown]
# ## Representacion grafica de los Datos.
#
# si a la funcion de tarazado se le dara una matriz de datos, la usara como coordenadas en el eje vertical, y utilizara el indice de cada punto de datos e el array como la coordenada horizontal.

# %%
plt.plot([1, 2, 5, 7, 8, 3, 1])
plt.show()

# %% [markdown]
# Tambien se puede proporcionar dos matrices: una para el eje horizontal y otra para el eje vertical

# %%
plt.plot([-3, -1, 0, 4, 7],[1, 4, 6, 7 ,8])
plt.show()

# %% [markdown]
# Pueden modificarse las longitudes de los ejes para que la figura no se vea tan ajustada.

# %%
plt.plot([-3, -1, 0, 4, 7],[1, 4, 6, 7 ,8])
plt.axis([-4, 8, 0, 10]) # [xmin, xmax, ymin, ymax]
plt.show()

# %% [markdown]
# Se sigue el mismo procedimiento para pintar  una funcion matematica

# %%
import numpy as np
x = np.linspace (-2, 2, 500)
y = x**2

plt.plot(x, y)
plt.show()

# %% [markdown]
# tambien puede modificarce el estilo de la grafica para que contenga mas informacion.

# %%
plt.plot(x, y)
plt.title("Square Function")
plt.xlabel("chido")
plt.ylabel("y =**2")
plt.grid(True)
plt.show()

# %% [markdown]
# Pueden suoeroinerse graficas y cambiar el estilo de las funciones.

# %%
import numpy as np 
x = np.linspace (-2, 2, 500)
y = x**2
y2 = x +1

plt.plot(x, y, 'b--', x, y2,'g')
plt.grid(True)
plt.show()

# %%
# separando en diferentes lineas las funciones
import numpy as np 
x = np.linspace (-2, 2, 500)
y = x**2
y2 = x +1

plt.title("Square Function")
plt.xlabel("chido")
plt.ylabel("y =**2")
plt.grid(True)

plt.plot(x, y, 'b--', label="x**2")
plt.plot(x, y2,'g',label = "x+1")
plt.legend(loc = "best")#La situa en la mejor localizacion
plt.show()

# %% [markdown]
# tambien pueden crearse dos graficas que no se superpongan, estas fraficas se organizan en un grid y se denominan subplots.

# %%
import numpy as np 
x = np.linspace (-2, 2, 500)
y = x**2
y2 = x +1

plt.subplot(1, 2, 1)# 1 Rows, 2 columns, 1st subplots
plt.plot(x, y, 'b--')
plt.subplot(1,2,2)# 1 Rows, 2 Columns, 2nd Subplots
plt.plot(x,y2,'g')

plt.show()

# %% [markdown]
# Para que las graficas no queden tan ajustadas, se puede hacer la figura mas grande.

# %%
plt.figure(figsize = (14,6))

plt.subplot(1, 2, 1) # 1 Rows, 2 columns, 1st subplots
plt.plot(x, y, 'b--')
plt.title("Square Function", fontsize =14)
plt.xlabel("chido" ,fontsize = 14)
plt.ylabel("y =**2",fontsize = 14)
plt.grid(True)
           
plt.subplot(1, 2, 2)Plots # 1 Rows, 2 columns, 1st subplots
plt.plot(x, y2, 'g')
plt.title("lineal Function", fontsize = 14)
plt.xlabel("chido2" ,fontsize = 14)
plt.ylabel("y =**2",fontsize = 14)
plt.grid(True)

plt.show()

# %% [markdown]
# ## scatter Plots

# %%
from numpy.random import rand
x, y = rand (2,100)
plt.scatter (x,y)
plt.show()

# %%
from numpy.random import rand 
x, y = rand (2,100)
x2, y2 = rand(2,100)
plt.scatter (x,y,c='red')
plt.scatter (x2,y2,c='blue')
plt.show()

# %% [markdown]
# ## Histogramas

# %%
data = [1,1.1, 1.8, 2, 2.1, 3.2, 3, 3, 3, 3]
plt.subplot(211)
plt.hist(data, bins = 10, rwidth = 0.8)

plt.subplot(212)
plt.hist(data, bins = [1, 1.5, 2, 2.5,3], rwidth = 0.95)

plt.xlabel('Value')
plt.xlabel('Frequency')

plt.show()

# %% [markdown]
# ## Guardar las figuras

# %%
from numpy.random import rand 
x, y = rand (2,100)
x2, y2 = rand(2,100)
plt.scatter (x,y,c='red')
plt.scatter (x2,y2,c='blue')

plt.savefig("3501_Mi_grafica_chida.png",transparent=True)
